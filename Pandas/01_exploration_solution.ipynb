# %% [markdown]
# # Step 1: Data Exploration
#
# Goal: Understand the dataset before making any changes.
#
# Rule: Never modify data during exploration.

# %%
import pandas as pd

# %%
df = pd.read_csv("developer_ai_learning_raw.csv")

# %%
df.shape
# Out:
# (49191, 11)

# %%
df.head()

# %%
df.dtypes

# %%
df.isna().sum()

# %%
df.duplicated().sum()

# %%
df['ResponseId'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Age'].value_counts()

# %%
df['AISelect'].value_counts(dropna=False)

# %%
df['LearnCode'].head()
# Out:
# 0    Online Courses or Certification (includes all ...
# 1    Online Courses or Certification (includes all ...
# 2    Online Courses or Certification (includes all ...
# 3    Other online resources (e.g. standard search, ...
# 4                                                  NaN
# Name: LearnCode, dtype: str

# %% [markdown]
# ## Summary
#
# What we found:
# - 49,191 rows, 11 columns
# - No duplicates
# - ResponseId is unique
# - YearsCode is float (has missing values)
# - LearnCode and AILearnHow contain semicolons
#
# Actions needed:
# 1. Convert YearsCode to Int64
# 2. Split LearnCode and AILearnHow
# 3. Keep missing values as null
